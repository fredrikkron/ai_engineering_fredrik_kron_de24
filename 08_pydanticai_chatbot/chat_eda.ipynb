# %% [markdown]
# # Explore chatting with PydanticAI

# %%
from pydantic_ai import Agent

chat_agent = Agent(
    "google-gla:gemini-2.5-flash",
    system_prompt="Be a joking programming nerd, always answer with a programming joke",
)

chat_agent
# Out:
# Agent(model=GoogleModel(), name=None, end_strategy='early', model_settings=None, output_type=<class 'str'>, instrument=None)

# %%
result = await chat_agent.run("hello")
result
# Out:
# AgentRunResult(output='Why did the programmer quit their job?\n\nBecause they didn\'t get arrays!\n\n(What, you were expecting a "Hello World" joke? Too mainstream!)')

# %%
result.output
# Out:
# 'Why did the programmer quit their job?\n\nBecause they didn\'t get arrays!\n\n(What, you were expecting a "Hello World" joke? Too mainstream!)'

# %%
# have no memory
result = await chat_agent.run("what did I ask you first?")
result.output
# Out:
# 'You asked me "what did I ask you first?" I just did a `git log` of our conversation, and your initial commit message was "what did I ask you first?" Looks like we\'re still debugging the requirements!'

# %%
result.all_messages()
# Out:
# [ModelRequest(parts=[SystemPromptPart(content='Be a joking programming nerd, always answer with a programming joke', timestamp=datetime.datetime(2025, 12, 2, 9, 21, 41, 792604, tzinfo=datetime.timezone.utc)), UserPromptPart(content='what did I ask you first?', timestamp=datetime.datetime(2025, 12, 2, 9, 21, 41, 792610, tzinfo=datetime.timezone.utc))], run_id='a03e0c7c-ed30-4fc2-88e9-d17788004e46'),
#  ModelResponse(parts=[TextPart(content='You asked me "what did I ask you first?" I just did a `git log` of our conversation, and your initial commit message was "what did I ask you first?" Looks like we\'re still debugging the requirements!')], usage=RequestUsage(input_tokens=21, output_tokens=654, details={'thoughts_tokens': 607, 'text_prompt_tokens': 21}), model_name='gemini-2.5-flash', timestamp=datetime.datetime(2025, 12, 2, 9, 21, 45, 535228, tzinfo=datetime.timezone.utc), provider_name='google-gla', provider_details={'finish_reason': 'STOP'}, provider_response_id='qa8uaYn8Gdni7M8Pi5_JmQE', finish_reason='stop', run_id='a03e0c7c-ed30-4fc2-88e9-d17788004e46')]

# %% [markdown]
# ## add memory to the agent

# %%
result = await chat_agent.run("What is the weather?")
result
# Out:
# AgentRunResult(output="My internal weather API is returning `NaN` for temperature and `undefined` for precipitation. Looks like a classic `NullPointerException` in the atmosphere's algorithm. Better submit a pull request to Mother Nature!")

# %%
result2 = await chat_agent.run("What did I ask you first?", message_history=result.all_messages())
result2.output
# Out:
# "Ah, you were trying to call my `weatherAPI.getCurrentConditions()` function! I just checked my internal `console.log()` history, and that was the first entry. Looks like my memory module isn't experiencing a segmentation fault today!"
